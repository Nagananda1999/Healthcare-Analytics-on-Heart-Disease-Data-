# %%
fig = data['disease'].value_counts().plot(kind = 'bar', color=["lightblue", 'lightgreen'],figsize=(10,10))
fig.set_xticklabels(labels=["Doesn't have heart disease",'1',' 2','3','Has heart disease'], rotation=0);
plt.title("Heart Disease values")
plt.ylabel("Amount");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [138], in <cell line: 2>()
#       1 fig = data['disease'].value_counts().plot(kind = 'bar', color=["lightblue", 'lightgreen'],figsize=(10,10))
# ----> 2 fig.set_xticklabels(labels=["Doesn't have heart disease",'1',' 2','3','Has heart disease'], rotation=0);
#       3 plt.title("Heart Disease values")
#       4 plt.ylabel("Amount")
#
# File C:\softwares\anaconda\lib\site-packages\matplotlib\axes\_base.py:75, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      74 def wrapper(self, *args, **kwargs):
# ---> 75     return get_method(self)(*args, **kwargs)
#
# File C:\softwares\anaconda\lib\site-packages\matplotlib\axis.py:1798, in Axis._set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1796 if fontdict is not None:
#    1797     kwargs.update(fontdict)
# ...

# %%
labels =  "Doesn't have heart disease",'1','2','3',"Has heart disease"
explode = (0, 0, 0, 0, 0)

fig1, ax1 = plt.subplots()
ax1.pie(data.target.value_counts(), explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(title = "Four Fruits:")
plt.show()

# %%
data.sex.value_counts()
# Out:
# 1    206
# 0     97
# Name: sex, dtype: int64

# %%
# convert 1,2,3,4 into 1 (or categorical variable)

# %%
import seaborn as sns

# %%
data.hist(bins=10, figsize=(20, 20), 
               column=data.columns[0:], color="DarkCyan", 
               grid=True)
plt.show()

# %%
data_corr = data.corr()

# %%
plt.figure(figsize=(14, 5))
sns.heatmap(round(data_corr, 2), annot=True, cmap="mako")
# Out:
# <AxesSubplot:>
